# %%
using Pkg
Pkg.activate(".")
# Out:
#   Activating project at `~/code/compositional`

# %%
using DataFrames, JLD2

include("./Data_Input.jl")
using .DataImport
# Out:
# WARNING: replacing module DataImport.

# %% [markdown]
# # Cross-sectional microbiome data

# %%
sep_data = DataImport.GetCrossSecData("./Data/crosssecdata.RData"; min_samples=1, min_counts=1, min_nreads=1);

for key in keys(sep_data)
    df = copy(sep_data[key])
    select!(df, Not([:project_id, :sample_id]))
    rename!(df, :otu_id => :species_id, :run_id => :sample_id)
    df.class .= "microbiome"
    df.environment .= key
    select!(df, :class, :environment, :species_id, :sample_id, :count, :nreads)
    sep_data[key] = df
end

# Join multiple dfs together (if they have the same columns)
all_df = vcat(values(sep_data)...)

@save "./Data/microbiome.jld2" all_df
# later
# @load "all_data.jld2" all_df

# %%
Pkg.add("CSV")
# Out:
#    Resolving package versions...
#   No Changes to `~/code/compositional/Project.toml`
#   No Changes to `~/code/compositional/Manifest.toml`
# Precompiling project...
#   10037.4 ms  ✓ CSV
#   1 dependency successfully precompiled in 11 seconds. 569 already precompiled.

# %%
using CSV#, CodecZlib

# Path to your file
# fname = "./data/sra.gene_sums.SRP014565.G026.gz"

# # Open a decompression stream over the gz file
# gz = GzipDecompressorStream(open(fname, "r"))

# # Read into a DataFrame
# df = CSV.read(gz, DataFrame; delim='\t')

# close(gz)  # tidy up

# # Inspect
# first(df, 5)
# Out:
# [ Info: Precompiling CSV [336ed68f-0bac-5ca0-87d4-7b16caf5d00b] (cache misses: wrong dep version loaded (8))
# ┌ Warning: Module ParsersExt with build ID fafbfcfd-cac6-739a-0000-2a225c2afd64 is missing from the cache.
# │ This may mean ParsersExt [f526588d-e68b-5dc5-a62e-ff9f36e48b1a] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2464
# ┌ Error: Error during loading of extension ParsersExt of InlineStrings, use `Base.retry_load_extensions()` to retry.
# │   exception =
# │    1-element ExceptionStack:
# │    Error when precompiling module, potentially caused by a __precompile__(false) declaration in the module.
# │    Stacktrace:
# │      [1] _require(pkg::Base.PkgId, env::Nothing)
# │        @ Base ./loading.jl:2468
# │      [2] __require_prelocked(uuidkey::Base.PkgId, env::Nothing)
# │        @ Base ./loading.jl:2315
# │      [3] #invoke_in_world#3
# │        @ ./essentials.jl:1089 [inlined]
# │      [4] invoke_in_world
# │        @ ./essentials.jl:1086 [inlined]
# │      [5] _require_prelocked
# │        @ ./loading.jl:2302 [inlined]
# │      [6] _require_prelocked
# │        @ ./loading.jl:2301 [inlined]
# │      [7] run_extension_callbacks(extid::Base.ExtensionId)
# │        @ Base ./loading.jl:1500
# │      [8] run_extension_callbacks(pkgid::Base.PkgId)
# │        @ Base ./loading.jl:1535
# │      [9] run_package_callbacks(modkey::Base.PkgId)
# │        @ Base ./loading.jl:1354
# │     [10] __require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base ./loading.jl:2326
# │     [11] #invoke_in_world#3
# │        @ ./essentials.jl:1089 [inlined]
# │     [12] invoke_in_world
# │        @ ./essentials.jl:1086 [inlined]
# │     [13] _require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base ./loading.jl:2302
# │     [14] macro expansion
# │        @ ./loading.jl:2241 [inlined]
# │     [15] macro expansion
# │        @ ./lock.jl:273 [inlined]
# │     [16] __require(into::Module, mod::Symbol)
# │        @ Base ./loading.jl:2198
# │     [17] #invoke_in_world#3
# │        @ ./essentials.jl:1089 [inlined]
# │     [18] invoke_in_world
# │        @ ./essentials.jl:1086 [inlined]
# │     [19] require(into::Module, mod::Symbol)
# │        @ Base ./loading.jl:2191
# │     [20] include
# │        @ ./Base.jl:557 [inlined]
# │     [21] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::Nothing)
# │        @ Base ./loading.jl:2790
# │     [22] top-level scope
# │        @ stdin:5
# │     [23] eval
# │        @ ./boot.jl:430 [inlined]
# │     [24] include_string(mapexpr::typeof(identity), mod::Module, code::String, filename::String)
# │        @ Base ./loading.jl:2643
# │     [25] include_string
# │        @ ./loading.jl:2653 [inlined]
# │     [26] exec_options(opts::Base.JLOptions)
# │        @ Base ./client.jl:321
# │     [27] _start()
# │        @ Base ./client.jl:531
# └ @ Base loading.jl:1506
# ┌ Warning: Module ParsersExt with build ID fafbfcfd-cac6-739a-0000-2a225c2afd64 is missing from the cache.
# │ This may mean ParsersExt [f526588d-e68b-5dc5-a62e-ff9f36e48b1a] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2464
# ┌ Error: Error during loading of extension ParsersExt of InlineStrings, use `Base.retry_load_extensions()` to retry.
# │   exception =
# │    1-element ExceptionStack:
# │    Error when precompiling module, potentially caused by a __precompile__(false) declaration in the module.
# │    Stacktrace:
# │      [1] _require(pkg::Base.PkgId, env::Nothing)
# │        @ Base ./loading.jl:2468
# │      [2] __require_prelocked(uuidkey::Base.PkgId, env::Nothing)
# │        @ Base ./loading.jl:2315
# │      [3] #invoke_in_world#3
# │        @ ./essentials.jl:1089 [inlined]
# │      [4] invoke_in_world
# │        @ ./essentials.jl:1086 [inlined]
# │      [5] _require_prelocked
# │        @ ./loading.jl:2302 [inlined]
# │      [6] _require_prelocked
# │        @ ./loading.jl:2301 [inlined]
# │      [7] run_extension_callbacks(extid::Base.ExtensionId)
# │        @ Base ./loading.jl:1500
# │      [8] run_extension_callbacks(pkgid::Base.PkgId)
# │        @ Base ./loading.jl:1535
# │      [9] run_package_callbacks(modkey::Base.PkgId)
# │        @ Base ./loading.jl:1354
# │     [10] __require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base ./loading.jl:2326
# │     [11] #invoke_in_world#3
# │        @ ./essentials.jl:1089 [inlined]
# │     [12] invoke_in_world
# │        @ ./essentials.jl:1086 [inlined]
# │     [13] _require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base ./loading.jl:2302
# │     [14] macro expansion
# │        @ ./loading.jl:2241 [inlined]
# │     [15] macro expansion
# │        @ ./lock.jl:273 [inlined]
# │     [16] __require(into::Module, mod::Symbol)
# │        @ Base ./loading.jl:2198
# │     [17] #invoke_in_world#3
# │        @ ./essentials.jl:1089 [inlined]
# │     [18] invoke_in_world
# │        @ ./essentials.jl:1086 [inlined]
# │     [19] require(into::Module, mod::Symbol)
# │        @ Base ./loading.jl:2191
# │     [20] include(mod::Module, _path::String)
# │        @ Base ./Base.jl:557
# │     [21] include(x::String)
# │        @ WeakRefStrings ~/.julia/packages/WeakRefStrings/31nkb/src/WeakRefStrings.jl:1
# │     [22] top-level scope
# │        @ ~/.julia/packages/WeakRefStrings/31nkb/src/WeakRefStrings.jl:548
# │     [23] include
# │        @ ./Base.jl:557 [inlined]
# │     [24] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
# │        @ Base ./loading.jl:2790
# │     [25] top-level scope
# │        @ stdin:5
# │     [26] eval
# │        @ ./boot.jl:430 [inlined]
# │     [27] include_string(mapexpr::typeof(identity), mod::Module, code::String, filename::String)
# │        @ Base ./loading.jl:2643
# │     [28] include_string
# │        @ ./loading.jl:2653 [inlined]
# │     [29] exec_options(opts::Base.JLOptions)
# │        @ Base ./client.jl:321
# │     [30] _start()
# │        @ Base ./client.jl:531
# └ @ Base loading.jl:1506
# ERROR: LoadError: MethodError: Cannot `convert` an object of type Parsers.PosLen to an object of type InlineStrings.String3
# The function `convert` exists, but no method is defined for this combination of argument types.
#
# Closest candidates are:
#   convert(::Type{T}, ::T) where T<:AbstractString
#    @ Base strings/basic.jl:231
#   convert(::Type{T}, ::AbstractString) where T<:AbstractString
#    @ Base strings/basic.jl:232
#   convert(::Type{T}, ::T) where T
#    @ Base Base.jl:126
#
# Stacktrace:
#   [1] setindex!(A::Vector{InlineStrings.String3}, x::Parsers.PosLen, i::Int64)
#     @ Base ./array.jl:976
#   [2] setindex!
#     @ ~/.julia/packages/SentinelArrays/vt8A6/src/SentinelArrays.jl:221 [inlined]
#   [3] parsevalue!(::Type{InlineStrings.String3}, buf::Vector{UInt8}, pos::Int64, len::Int64, row::Int64, rowoffset::Int64, i::Int64, col::CSV.Column, ctx::CSV.Context)
#     @ CSV ~/.julia/packages/CSV/XLcqT/src/file.jl:796
#   [4] parserow
#     @ ~/.julia/packages/CSV/XLcqT/src/file.jl:632 [inlined]
#   [5] parsefilechunk!(ctx::CSV.Context, pos::Int64, len::Int64, rowsguess::Int64, rowoffset::Int64, columns::Vector{CSV.Column}, ::Type{Tuple{}})
#     @ CSV ~/.julia/packages/CSV/XLcqT/src/file.jl:556
#   [6] CSV.File(ctx::CSV.Context, chunking::Bool)
#     @ CSV ~/.julia/packages/CSV/XLcqT/src/file.jl:290
#   [7] File
#     @ ~/.julia/packages/CSV/XLcqT/src/file.jl:227 [inlined]
#   [8] #File#32
#     @ ~/.julia/packages/CSV/XLcqT/src/file.jl:223 [inlined]
#   [9] CSV.File(source::IOBuffer)
#     @ CSV ~/.julia/packages/CSV/XLcqT/src/file.jl:162
#  [10] macro expansion
#     @ ~/.julia/packages/CSV/XLcqT/src/precompile.jl:10 [inlined]
#  [11] macro expansion
#     @ ~/.julia/packages/PrecompileTools/L8A3n/src/workloads.jl:78 [inlined]
#  [12] macro expansion
#     @ ~/.julia/packages/CSV/XLcqT/src/precompile.jl:7 [inlined]
#  [13] macro expansion
#     @ ~/.julia/packages/PrecompileTools/L8A3n/src/workloads.jl:140 [inlined]
#  [14] top-level scope
#     @ ~/.julia/packages/CSV/XLcqT/src/precompile.jl:139
#  [15] include(mod::Module, _path::String)
#     @ Base ./Base.jl:557
#  [16] include(x::String)
#     @ CSV ~/.julia/packages/CSV/XLcqT/src/CSV.jl:24
#  [17] top-level scope
#     @ ~/.julia/packages/CSV/XLcqT/src/CSV.jl:120
#  [18] include
#     @ ./Base.jl:557 [inlined]
#  [19] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::Nothing)
#     @ Base ./loading.jl:2790
#  [20] top-level scope
#     @ stdin:5
# in expression starting at /home/luca/.julia/packages/CSV/XLcqT/src/precompile.jl:3
# in expression starting at /home/luca/.julia/packages/CSV/XLcqT/src/CSV.jl:1
# in expression starting at stdin:5
# Failed to precompile CSV [336ed68f-0bac-5ca0-87d4-7b16caf5d00b] to "/home/luca/.julia/compiled/v1.11/CSV/jl_y3xjxr".
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base ./error.jl:35
#   [2] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool; flags::Cmd, cacheflags::Base.CacheFlags, reasons::Dict{String, Int64}, isext::Bool)
#     @ Base ./loading.jl:3085
#   [3] (::Base.var"#1082#1083"{Base.PkgId})()
#     @ Base ./loading.jl:2492
#   [4] mkpidlock(f::Base.var"#1082#1083"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
#     @ FileWatching.Pidfile ~/.julia/juliaup/julia-1.11.1+0.x64.linux.gnu/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:95
#   [5] #mkpidlock#6
#     @ ~/.julia/juliaup/julia-1.11.1+0.x64.linux.gnu/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:90 [inlined]
#   [6] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
#     @ FileWatching.Pidfile ~/.julia/juliaup/julia-1.11.1+0.x64.linux.gnu/share/julia/stdlib/v1.11/FileWatching/src/pidfile.jl:116
#   [7] #invokelatest#2
#     @ ./essentials.jl:1057 [inlined]
#   [8] invokelatest
#     @ ./essentials.jl:1052 [inlined]
#   [9] maybe_cachefile_lock(f::Base.var"#1082#1083"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
#     @ Base ./loading.jl:3609
#  [10] maybe_cachefile_lock
#     @ ./loading.jl:3606 [inlined]
#  [11] _require(pkg::Base.PkgId, env::String)
#     @ Base ./loading.jl:2488
#  [12] __require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base ./loading.jl:2315
#  [13] #invoke_in_world#3
#     @ ./essentials.jl:1089 [inlined]
#  [14] invoke_in_world
#     @ ./essentials.jl:1086 [inlined]
#  [15] _require_prelocked(uuidkey::Base.PkgId, env::String)
#     @ Base ./loading.jl:2302
#  [16] macro expansion
#     @ ./loading.jl:2241 [inlined]
#  [17] macro expansion
#     @ ./lock.jl:273 [inlined]
#  [18] __require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:2198
#  [19] #invoke_in_world#3
#     @ ./essentials.jl:1089 [inlined]
#  [20] invoke_in_world
#     @ ./essentials.jl:1086 [inlined]
#  [21] require(into::Module, mod::Symbol)
#     @ Base ./loading.jl:2191
