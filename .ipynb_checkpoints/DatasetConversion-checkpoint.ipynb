# %%
using Pkg
Pkg.activate(".")
# Out:
#   Activating project at `~/code/compositional`

# %%
using DataFrames, JLD2
using CSV, CodecZlib

include("./Data_Input.jl")
using .DataImport

# %% [markdown]
# # Cross-sectional microbiome data

# %%
sep_data = DataImport.GetCrossSecData("./Data/crosssecdata.RData"; min_samples=1, min_counts=1, min_nreads=1);

for key in keys(sep_data)
    df = copy(sep_data[key])
    select!(df, Not([:project_id, :sample_id]))
    rename!(df, :otu_id => :species_id, :run_id => :sample_id)
    df.env .= key
    select!(df, :env, :species_id, :sample_id, :count, :nreads)
    sep_data[key] = df
end

# Join multiple dfs together (if they have the same columns)
all_df = vcat(values(sep_data)...)

@save "./Data/processed/microbiome.jld2" all_df

# %%
@load "./Data/processed/microbiome.jld2" all_df
first(all_df, 5)
# Out:
# 5×5 DataFrame
#  Row │ env       species_id  sample_id   count    nreads
#      │ String    Int32       String      Float64  Float64
# ─────┼────────────────────────────────────────────────────
#    1 │ SEAWATER      107380  SRR6457279      7.0  73003.0
#    2 │ SEAWATER      149885  SRR6457279      1.0  73003.0
#    3 │ SEAWATER      118090  SRR6457279      6.0  73003.0
#    4 │ SEAWATER      103181  SRR6457279    854.0  73003.0
#    5 │ SEAWATER       83222  SRR6457279      1.0  73003.0

# %% [markdown]
# # Genetic expression data

# %%
# Load file with metadata info to get nreads for each sample
fname = "./Data/GTEx_Analysis_v10_Annotations_SampleAttributesDS.txt"
df_reads = CSV.read(fname, DataFrame; delim='\t')
df_reads = select(df_reads, :SAMPID, :SMRDTTL)
rename!(df_reads, :SAMPID => :sample_id, :SMRDTTL => :nreads)

# Loop over different datasets to make a unique DataFrame
fnames = ["brain_cortex", "heart_left_ventricle", "liver", "pancreas"]
df_names = ["BRAIN", "HEART", "LIVER", "PANCREAS"]
all_df = []

for i in 1:length(fnames)
    fname = "./Data/gene_reads_v10_$(fnames[i]).gct.gz"
    
    # Open a decompression stream over the gz file
    gz = GzipDecompressorStream(open(fname, "r"))
    
    # Read into a DataFrame
    df_raw = CSV.File(
        gz;
        delim='\t',
        header=3,
        strict=false,    # allow rows with varying column counts
    ) |> DataFrame
    
    close(gz)
    
    select!(df_raw, Not([:Description]))
    df = stack(df_raw, Not(:Name); variable_name = :sample_id, value_name = :counts)
    filter!(:counts => x -> x .> 0, df)
    rename!(df, :Name => :species_id, :counts => :count)
    df.env .= df_names[i]
    select!(df, :env, :species_id, :sample_id, :count)
    df = leftjoin(df, df_reads, on = :sample_id)
    push!(all_df, df)
end
    
# Join multiple dfs together (if they have the same columns)
all_df = vcat(all_df...)

@save "./Data/processed/genetic.jld2" all_df

# %%
@load "./Data/processed/genetic.jld2" all_df
first(all_df, 5)
# Out:
# 5×5 DataFrame
#  Row │ env     species_id         sample_id                 count  nreads
#      │ String  String31           String                    Int64  Float64?
# ─────┼───────────────────────────────────────────────────────────────────────
#    1 │ BRAIN   ENSG00000223972.5  GTEX-1117F-3226-SM-5N9CT      1  8.46893e7
#    2 │ BRAIN   ENSG00000227232.5  GTEX-1117F-3226-SM-5N9CT    282  8.46893e7
#    3 │ BRAIN   ENSG00000268020.3  GTEX-1117F-3226-SM-5N9CT      1  8.46893e7
#    4 │ BRAIN   ENSG00000240361.2  GTEX-1117F-3226-SM-5N9CT      1  8.46893e7
#    5 │ BRAIN   ENSG00000186092.7  GTEX-1117F-3226-SM-5N9CT      5  8.46893e7

# %% [markdown]
# # Fossil occurances data

# %%
fnames = ["africa.csv", "asia.csv", "europe.csv", "north_america.csv", "oceania.csv", "south_america.csv"]
df_names = ["AFRICA", "ASIA", "EUROPE", "NORTH AMERICA", "OCEANIA", "SOUTH AMERICA"]
all_df = []

for i in 1:length(fnames)
    df = CSV.File("./Data/fossils_raw/$(fnames[i])"; header=17) |> DataFrame
    grouped = combine(groupby(df, [:collection_no, :accepted_name]), nrow => :count)
    rename!(grouped, :collection_no => :sample_id, :accepted_name => :species_id)
    grouped.env .= df_names[i]
    sample_sums = combine(groupby(grouped, :sample_id), :count => sum => :nreads)
    df = leftjoin(grouped, sample_sums, on = :sample_id)
    filter!(row -> !ismissing(row.sample_id) && !ismissing(row.species_id) && row.species_id != "", df)
    
    # Step 8: Reorder columns
    select!(df, :env, :species_id, :sample_id, :count, :nreads)
    
    # Step 9: Append to master collection
    push!(all_df, df)
end

# Join multiple dfs together (if they have the same columns)
all_df = vcat(all_df...)

@save "./Data/processed/fossils.jld2" all_df

# %%
@load "./Data/processed/fossils.jld2" all_df
first(all_df, 5)
# Out:
# 5×5 DataFrame
#  Row │ env     species_id             sample_id  count  nreads
#      │ String  String                 Int64      Int64  Int64?
# ─────┼─────────────────────────────────────────────────────────
#    1 │ AFRICA  Brabovus nanincisus        32050      1      85
#    2 │ AFRICA  Malletia                    1329      1      27
#    3 │ AFRICA  Trigonarca angolensis       1329      1      27
#    4 │ AFRICA  Trigonarca furoni           1329      1      27
#    5 │ AFRICA  Pseudocucullaea lens        1329      1      27
